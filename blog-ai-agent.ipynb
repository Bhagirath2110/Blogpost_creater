# %% [markdown]
# 1.1: Install dependencies
# The Kaggle Notebooks environment includes a pre-installed version of the google-adk library for Python and its required dependencies, so you don't need to install additional packages in this notebook.
#
# To install and use ADK in your own Python development environment outside of this, you can do so by running:
#
# pip install google-adk

# %%
# pip install google-adk

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %% [markdown]
# 1.2: Configure your Gemini API Key

# %%
import os
from kaggle_secrets import UserSecretsClient

try:
    GOOGLE_API_KEY = UserSecretsClient().get_secret("GOOGLE_API_KEY")
    os.environ["GOOGLE_API_KEY"] = GOOGLE_API_KEY
    print("✅ Gemini API key setup complete.")
except Exception as e:
    print(
        f"🔑 Authentication Error: Please make sure you have added 'GOOGLE_API_KEY' to your Kaggle secrets. Details: {e}"
    )
# Out:
# ✅ Gemini API key setup complete.

# %% [markdown]
# 1.3: Import ADK components

# %%
from google.adk.agents import Agent, SequentialAgent, ParallelAgent, LoopAgent
from google.adk.models.google_llm import Gemini
from google.adk.runners import InMemoryRunner
from google.adk.tools import AgentTool, FunctionTool, google_search
from google.genai import types

print("✅ ADK components imported successfully.")
# Out:
# ✅ ADK components imported successfully.

# %% [markdown]
# 1.4: Configure Retry Options

# %%
retry_config=types.HttpRetryOptions(
    attempts=5,  # Maximum retry attempts
    exp_base=7,  # Delay multiplier
    initial_delay=1,
    http_status_codes=[429, 500, 503, 504], # Retry on these HTTP errors
)

# %% [markdown]
# Architecture: Blog Post Creation Pipeline

# %%
outline_agent = Agent(
    name="OutlineAgent",
    model=Gemini(
        model="gemini-2.5-flash-lite",
        retry_options=retry_config
    ),
    instruction="""Create a blog outline for the given topic with:
    1. A catchy headline
    2. An introduction hook
    3. 3-5 main sections with 2-3 bullet points for each
    4. A concluding thought""",
    output_key="blog_outline",  # The result of this agent will be stored in the session state with this key.
)

print("✅ outline_agent created.")
# Out:
# ✅ outline_agent created.

# %%
writer_agent = Agent(
    name="WriterAgent",
    model=Gemini(
        model="gemini-2.5-flash-lite",
        retry_options=retry_config
    ),
    # The `{blog_outline}` placeholder automatically injects the state value from the previous agent's output.
    instruction="""Following this outline strictly: {blog_outline}
    Write a brief, 200 to 300-word blog post with an engaging and informative tone.""",
    output_key="blog_draft",  # The result of this agent will be stored with this key.
)

print("✅ writer_agent created.")
# Out:
# ✅ writer_agent created.

# %%
# Editor Agent: Edits and polishes the draft from the writer agent.
editor_agent = Agent(
    name="EditorAgent",
    model=Gemini(
        model="gemini-2.5-flash-lite",
        retry_options=retry_config
    ),
    # This agent receives the `{blog_draft}` from the writer agent's output.
    instruction="""Edit this draft: {blog_draft}
    Your task is to polish the text by fixing any grammatical errors, improving the flow and sentence structure, and enhancing overall clarity.""",
    output_key="final_blog",  # This is the final output of the entire pipeline.
)

print("✅ editor_agent created.")
# Out:
# ✅ editor_agent created.

# %%
root_agent = SequentialAgent(
    name="BlogPipeline",
    sub_agents=[outline_agent, writer_agent, editor_agent],
)

print("✅ Sequential Agent created.")
# Out:
# ✅ Sequential Agent created.

# %%
runner = InMemoryRunner(agent=root_agent)
response = await runner.run_debug(
    "Write a blog post about the benefits of agentic ai in industries"
)
# Out:
#  ### Created new session: debug_session_id
#
# User > Write a blog post about the benefits of agentic ai in industries
# OutlineAgent > ## Blog Outline:
#
# **Headline:** Unleash the Power: How Agentic AI is Revolutionizing Industries
#
# **Introduction Hook:** Imagine an AI that doesn't just process data, but *acts* on it. That's the promise of Agentic AI, a paradigm shift poised to redefine efficiency, innovation, and problem-solving across every sector. Get ready to discover how these intelligent agents are moving beyond passive analysis to become active collaborators and game-changers in the business world.
#
# ---
#
# **Main Sections:**
#
# **1. Beyond Automation: The Rise of Proactive Problem Solvers**
#     *   **Intelligent Decision-Making:** Agentic AI can analyze complex scenarios, weigh multiple factors, and make autonomous decisions that optimize outcomes, from supply chain logistics to financial forecasting.
#     *   **Adaptive Learning and Optimization:** Unlike rigid automation, agents continuously learn from their environment and adapt their strategies in real-time, leading to ongoing improvements and efficiency gains.
#     *   **Personalized Customer Experiences:** Agents can understand individual customer needs and proactively offer tailored solutions, recommendations, and support, fostering deeper engagement and loyalty.
#
# **2. Supercharging Efficiency and Productivity**
#     *   **Automating Complex Workflows:** Agentic AI can orchestrate intricate multi-step processes, managing tasks, resources, and dependencies far more effectively than traditional automation.
#     *   **Accelerated Research and Development:** Agents can sift through vast datasets, identify patterns, and even propose hypotheses, drastically speeding up discovery in fields like drug development or materials science.
#     *   **Streamlined Operations and Resource Management:** From predicting equipment failures to optimizing energy consumption, agents can proactively manage operational assets, minimizing downtime and waste.
#
# **3. Empowering Human Teams and Driving Innovation**
#     *   **Augmented Human Capabilities:** Agents act as intelligent assistants, handling routine tasks and providing critical insights, allowing human experts to focus on higher-level strategy and creativity.
#     *   **Unlocking New Business Models:** The ability of agents to independently identify opportunities and execute strategies can lead to the creation of entirely new services and revenue streams.
#     *   **Enhanced Risk Management and Compliance:** Agents can continuously monitor for potential risks, identify non-compliance, and even initiate corrective actions, safeguarding businesses.
#
# ---
#
# **Concluding Thought:** Agentic AI is not just an evolution of artificial intelligence; it's a fundamental transformation. By empowering AI with the ability to perceive, reason, and act autonomously, industries stand on the cusp of unprecedented levels of efficiency, innovation, and strategic advantage. The future of business is intelligent, proactive, and undeniably agentic.
# WriterAgent > ## Unleash the Power: How Agentic AI is Revolutionizing Industries
#
# Imagine an AI that doesn't just process data, but *acts* on it. That's the promise of Agentic AI, a paradigm shift poised to redefine efficiency, innovation, and problem-solving across every sector. Get ready to discover how these intelligent agents are moving beyond passive analysis to become active collaborators and game-changers in the business world.
#
# Agentic AI represents a leap beyond traditional automation. These aren't just scripts executing pre-defined tasks; they are proactive problem solvers. With intelligent decision-making capabilities, they can analyze complex scenarios, weigh myriad factors, and autonomously optimize outcomes in areas like supply chain logistics and financial forecasting. Crucially, they engage in adaptive learning, continuously refining their strategies based on real-time environmental feedback, leading to ongoing improvements and efficiency gains. This adaptability also fuels personalized customer experiences, with agents understanding individual needs to offer tailored solutions and support, fostering deeper engagement.
#
# The impact on productivity is immense. Agentic AI can orchestrate intricate, multi-step workflows, manage resources, and handle dependencies far more effectively than conventional automation. In research and development, agents accelerate discovery by sifting through vast datasets and proposing hypotheses. Operations benefit from proactive management of assets, from predicting equipment failures to optimizing energy consumption, thus minimizing downtime and waste. Furthermore, agentic AI empowers human teams by acting as intelligent assistants, freeing up experts to focus on strategy and creativity, while also unlocking new business models and enhancing risk management through continuous monitoring and automated corrective actions.
#
# Agentic AI is not merely an evolution; it's a transformation. By granting AI the ability to perceive, reason, and act autonomously, industries are poised for unprecedented levels of efficiency, innovation, and strategic advantage. The future of business is intelligent, proactive, and undeniably agentic.
# EditorAgent > ## Unleash the Power: How Agentic AI is Revolutionizing Industries
#
# Imagine an AI that doesn't just process data, but *acts* on it. That's the promise of Agentic AI, a paradigm shift poised to redefine efficiency, innovation, and problem-solving across every sector. Prepare to discover how these intelligent agents are moving beyond passive analysis to become active collaborators and true game-changers in the business world.
#
# Agentic AI marks a significant leap beyond traditional automation. These are not mere scripts executing pre-defined tasks; they are proactive problem solvers. Equipped with intelligent decision-making capabilities, they can analyze complex scenarios, weigh myriad factors, and autonomously optimize outcomes in critical areas such as supply chain logistics and financial forecasting. Crucially, they engage in adaptive learning, continuously refining their strategies based on real-time environmental feedback, which leads to ongoing improvements and substantial efficiency gains. This adaptability also fuels hyper-personalized customer experiences, as agents learn individual needs to offer tailored solutions and support, fostering deeper engagement.
#
# The impact on productivity is immense. Agentic AI can orchestrate intricate, multi-step workflows, manage resources, and handle dependencies far more effectively than conventional automation. In research and development, these agents accelerate discovery by sifting through vast datasets and proposing hypotheses, drastically speeding up innovation. Operations benefit from proactive asset management, from predicting equipment failures to optimizing energy consumption, thereby minimizing downtime and waste. Furthermore, agentic AI empowers human teams by acting as intelligent assistants, freeing up experts to focus on strategy and creativity. This technology also unlocks entirely new business models and enhances risk management through continuous monitoring and automated corrective actions.
#
# Agentic AI is not simply an evolution; it's a transformation. By granting AI the ability to perceive, reason, and act autonomously, industries are poised for unprecedented levels of efficiency, innovation, and strategic advantage. The future of business is intelligent, proactive, and undeniably agentic.
